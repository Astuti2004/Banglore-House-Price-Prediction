# %% [markdown]
# <a href="https://colab.research.google.com/github/Astuti2004/Banglore-House-Price-Prediction/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from PIL import Image, ImageEnhance

# For ML Models
from tensorflow import keras
from tensorflow.keras.layers import *
from tensorflow.keras.losses import *
from tensorflow.keras.models import *
from tensorflow.keras.metrics import *
from tensorflow.keras.optimizers import *
from tensorflow.keras.applications import *
from tensorflow.keras.preprocessing.image import load_img
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import Model

from tensorflow.keras.utils import plot_model
from tensorflow.keras.layers import Input, Dense, BatchNormalization
from IPython.core.display import Image

# For Data Visualization
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm
import random
import os
import keras
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from PIL import Image
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('dark_background')
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-215fd318-5aaf-428f-b704-54a5f0c483cd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-215fd318-5aaf-428f-b704-54a5f0c483cd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import zipfile
import os

zip_path = "/content/archive (7).zip"  # replace if different
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall("dataset")

print("Extracted to 'dataset/'")
# Out:
# Extracted to 'dataset/'

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-6c35b4b7-e979-4efa-a7c5-939e452a927d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6c35b4b7-e979-4efa-a7c5-939e452a927d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
train_dir = '/content/archive (7) (1).zip'
test_dir = '/content/archive (8) (1).zip'

train_paths = []
train_labels = []

for label in os.listdir(train_dir):
    for image in os.listdir(train_dir+label):
        train_paths.append(train_dir+label+'/'+image)
        train_labels.append(label)

train_paths, train_labels = shuffle(train_paths, train_labels)
# Out:
# ---------------------------------------------------------------------------
# NotADirectoryError                        Traceback (most recent call last)
# /tmp/ipython-input-1537414143.py in <cell line: 0>()
#       5 train_labels = []
#       6
# ----> 7 for label in os.listdir(train_dir):
#       8     for image in os.listdir(train_dir+label):
#       9         train_paths.append(train_dir+label+'/'+image)
#
# NotADirectoryError: [Errno 20] Not a directory: '/content/archive (7) (1).zip'

# %%
import zipfile

zip_path = '/content/archive (7) (1).zip'
zip_path = '/content/archive (8) (1).zip'  # your uploaded file
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall('dataset')  # extracts into /content/dataset/

# %%
import os
os.listdir('dataset')
# Out:
# ['yes', 'Training', 'brain_tumor_dataset', 'no', 'Testing']

# %%
train_dir = 'dataset/Training/'
train_paths = []
train_labels = []

for label in os.listdir(train_dir):
    label_path = os.path.join(train_dir, label)
    for image in os.listdir(label_path):
        train_paths.append(os.path.join(label_path, image))
        train_labels.append(label)

print("Total images:", len(train_paths))
# Out:
# Total images: 5712

# %%
train_paths = []
train_labels = []

for label in os.listdir(train_dir):
    for image in os.listdir(train_dir+label):
        train_paths.append(train_dir+label+'/'+image)
        train_labels.append(label)

train_paths, train_labels = shuffle(train_paths, train_labels)

# %%
plt.figure(figsize=(14,6))
colors = ['#4285f4', '#ea4335', '#fbbc05', '#34a853']
plt.rcParams.update({'font.size': 14})
plt.pie([len([x for x in train_labels if x=='pituitary']),
         len([x for x in train_labels if x=='notumor']),
         len([x for x in train_labels if x=='meningioma']),
         len([x for x in train_labels if x=='glioma'])],
        labels=['pituitary','notumor', 'meningioma', 'glioma'],
        colors=colors, autopct='%.1f%%', explode=(0.025,0.025,0.025,0.025),
        startangle=30);

# %%
test_paths = []
test_labels = []

for label in os.listdir(test_dir):
    for image in os.listdir(test_dir+label):
        test_paths.append(test_dir+label+'/'+image)
        test_labels.append(label)

test_paths, test_labels = shuffle(test_paths, test_labels)

# %%
import zipfile

zip_path = '/content/archive (8) (1).zip'  # update if filename is different
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall('dataset')  # unzips into /content/dataset/

# %%
from sklearn.utils import shuffle

# TRAIN
train_dir = 'dataset/Training/'
train_paths = []
train_labels = []

for label in os.listdir(train_dir):
    label_path = os.path.join(train_dir, label)
    for image in os.listdir(label_path):
        train_paths.append(os.path.join(label_path, image))
        train_labels.append(label)

# TEST
test_dir = 'dataset/Testing/'
test_paths = []
test_labels = []

for label in os.listdir(test_dir):
    label_path = os.path.join(test_dir, label)
    for image in os.listdir(label_path):
        test_paths.append(os.path.join(label_path, image))
        test_labels.append(label)

# Shuffle
train_paths, train_labels = shuffle(train_paths, train_labels)
test_paths, test_labels = shuffle(test_paths, test_labels)

print("Training images:", len(train_paths))
print("Testing images:", len(test_paths))
# Out:
# Training images: 5712
# Testing images: 1311

# %%
plt.figure(figsize=(14,6))
colors = ['#4285f4', '#ea4335', '#fbbc05', '#34a853']
plt.rcParams.update({'font.size': 14})
plt.pie([len(train_labels), len(test_labels)],
        labels=['Train','Test'],
        colors=colors, autopct='%.1f%%', explode=(0.05,0),
        startangle=30);

# %%
def augment_image(image):
    image = Image.fromarray(np.uint8(image))
    image = ImageEnhance.Brightness(image).enhance(random.uniform(0.8,1.2))
    image = ImageEnhance.Contrast(image).enhance(random.uniform(0.8,1.2))
    image = np.array(image)/255.0
    return image

# %%
IMAGE_SIZE = 128

def open_images(paths):
    '''
    Given a list of paths to images, this function returns the images as arrays (after augmenting them)
    '''
    images = []
    for path in paths:
        image = load_img(path, target_size=(IMAGE_SIZE,IMAGE_SIZE))
        image = augment_image(image)
        images.append(image)
    return np.array(images)

images = open_images(train_paths[50:59])
labels = train_labels[50:59]
fig = plt.figure(figsize=(12, 6))
for x in range(1, 9):
    fig.add_subplot(2, 4, x)
    plt.axis('off')
    plt.title(labels[x])
    plt.imshow(images[x])
plt.rcParams.update({'font.size': 12})
plt.show()

# %%
unique_labels = os.listdir(train_dir)

def encode_label(labels):
    encoded = []
    for x in labels:
        encoded.append(unique_labels.index(x))
    return np.array(encoded)

def decode_label(labels):
    decoded = []
    for x in labels:
        decoded.append(unique_labels[x])
    return np.array(decoded)

def datagen(paths, labels, batch_size=12, epochs=1):
    for _ in range(epochs):
      for x in range(0, len(paths), batch_size):
            batch_paths = paths[x:x+batch_size]
            batch_images = open_images(batch_paths)
            batch_labels = labels[x:x+batch_size]
            batch_labels = encode_label(batch_labels)
            yield batch_images, batch_labels

# %%
base_model = VGG16(input_shape=(IMAGE_SIZE,IMAGE_SIZE,3), include_top=False, weights='imagenet')
# Set all layers to non-trainable
for layer in base_model.layers:
    layer.trainable = False
# Set the last vgg block to trainable
base_model.layers[-2].trainable = True
base_model.layers[-3].trainable = True
base_model.layers[-4].trainable = True

model = Sequential()
model.add(Input(shape=(IMAGE_SIZE,IMAGE_SIZE,3)))
model.add(base_model)
model.add(Flatten())
model.add(Dropout(0.3))
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(len(unique_labels), activation='softmax'))
# Out:
# ...
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ vgg16 (Functional)              │ (None, 4, 4, 512)      │    14,714,688 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 8192)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 8192)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │     1,048,704 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ...

# %%
model.compile(optimizer=Adam(learning_rate=0.0001),
             loss='sparse_categorical_crossentropy',
             metrics=['sparse_categorical_accuracy'])

# %%
batch_size = 20
steps = int(len(train_paths)/batch_size)
epochs = 5
history = model.fit(datagen(train_paths, train_labels, batch_size=batch_size, epochs=epochs),
                    epochs=epochs, steps_per_epoch=steps)
# Out:
# Epoch 1/5
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 866s 3s/step - loss: 0.6305 - sparse_categorical_accuracy: 0.7578
# Epoch 2/5
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 858s 3s/step - loss: 0.2550 - sparse_categorical_accuracy: 0.8978
# Epoch 3/5
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 855s 3s/step - loss: 0.1585 - sparse_categorical_accuracy: 0.9436
# Epoch 4/5
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 854s 3s/step - loss: 0.1075 - sparse_categorical_accuracy: 0.9577
# Epoch 5/5
# 285/285 ━━━━━━━━━━━━━━━━━━━━ 854s 3s/step - loss: 0.1016 - sparse_categorical_accuracy: 0.9621

# %%
plt.figure(figsize=(8,4))
plt.grid(True)
plt.plot(history.history['sparse_categorical_accuracy'], '.g-', linewidth=2)
plt.plot(history.history['loss'], '.r-', linewidth=2)
plt.title('Model Training History')
plt.xlabel('epoch')
plt.xticks([x for x in range(epochs)])
plt.legend(['Accuracy', 'Loss'], loc='upper left', bbox_to_anchor=(1, 1))
plt.show()

# %%
batch_size = 32
steps = int(len(test_paths)/batch_size)
y_pred = []
y_true = []
for x,y in tqdm(datagen(test_paths, test_labels, batch_size=batch_size, epochs=1), total=steps):
    pred = model.predict(x)
    pred = np.argmax(pred, axis=-1)
    for i in decode_label(pred):
        y_pred.append(i)
    for i in decode_label(y):
        y_true.append(i)
# Out:
#   0%|          | 0/40 [00:00<?, ?it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step
#   2%|▎         | 1/40 [00:05<03:27,  5.33s/it]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
#   5%|▌         | 2/40 [00:09<02:53,  4.57s/it]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
#   8%|▊         | 3/40 [00:14<03:00,  4.88s/it]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
#  10%|█         | 4/40 [00:19<03:00,  5.01s/it]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
#  12%|█▎        | 5/40 [00:23<02:41,  4.61s/it]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
#  15%|█▌        | 6/40 [00:28<02:44,  4.83s/it]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
#  18%|█▊        | 7/40 [00:34<02:43,  4.96s/it]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
#  20%|██        | 8/40 [00:39<02:41,  5.05s/it]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
#  22%|██▎       | 9/40 [00:43<02:25,  4.68s/it]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
#  25%|██▌       | 10/40 [00:47<02:12,  4.43s/it]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
#  28%|██▊       | 11/40 [00:51<02:07,  4.38s/it]
# ...

# %%
print(classification_report(y_true, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#       glioma       0.95      0.89      0.92       300
#   meningioma       0.88      0.96      0.92       306
#      notumor       1.00      0.98      0.99       405
#    pituitary       0.98      0.98      0.98       300
#
#     accuracy                           0.95      1311
#    macro avg       0.95      0.95      0.95      1311
# weighted avg       0.96      0.95      0.95      1311

# %%
def names(number):
    if number==0:
        return 'No, Its not a tumor'
    else:
        return 'Its a Tumor'

# %%
from PIL import Image

# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

# Assuming you've already trained and loaded your model
# model = keras.models.load_model("path_to_your_model.h5")

# Step 1: Load the image
img = Image.open("/kaggle/input/brain-tumor-mri-dataset/Training/glioma/Tr-glTr_0002.jpg")

# Step 2: Preprocess the image
x = np.array(img.resize((128, 128)))           # Resize image to match model input
x = x / 255.0                                   # Normalize pixel values to [0,1]
x = x.reshape(1, 128, 128, 3)                   # Reshape for prediction (Batch size, Height, Width, Channels)

# Step 3: Predict
res = model.predict(x)                          # Predict class probabilities
classification = np.argmax(res, axis=1)[0]      # Get index of highest probability

# Step 4: Define class names
names = ['Glioma', 'Meningioma', 'No Tumor', 'Pituitary Tumor']  # Change according to your dataset

# Step 5: Display the image and prediction
plt.imshow(img)
plt.axis('off')
plt.title(f"{res[0][classification]*100:.2f}% Confidence\nConclusion: {names[classification]}")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-843105632.py in <cell line: 0>()
#       7
#       8 # Step 1: Load the image
# ----> 9 img = Image.open("/kaggle/input/brain-tumor-mri-dataset/Training/glioma/Tr-glTr_0002.jpg")
#      10
#      11 # Step 2: Preprocess the image
#
# /usr/local/lib/python3.11/dist-packages/PIL/Image.py in open(fp, mode, formats)
#    3511     if is_path(fp):
#    3512         filename = os.fspath(fp)
# -> 3513         fp = builtins.open(filename, "rb")
#    3514         exclusive_fp = True
#    3515     else:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/kaggle/input/brain-tumor-mri-dataset/Training/glioma/Tr-glTr_0002.jpg'

# %%
# !pip install gradio tensorflow pillow

# %%
import gradio as gr
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image
import numpy as np
from PIL import Image

# %%
# Out:
#   File "/tmp/ipython-input-1240613022.py", line 1
#     model = load_model("os.listdir()
#                        ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
import os
os.listdir()
# Out:
# ['.config',
#  'archive (8) (1).zip',
#  'dataset',
#  'archive (7).zip',
#  'archive (7) (1).zip',
#  'archive (8).zip',
#  'sample_data']

# %%
from tensorflow.keras.models import load_model

model = load_model('Untitled2.ipynb')  # Replace with actual name
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-3137685664.py in <cell line: 0>()
#       1 from tensorflow.keras.models import load_model
#       2
# ----> 3 model = load_model('Untitled2.ipynb')  # Replace with actual name
#
# /usr/local/lib/python3.11/dist-packages/keras/src/saving/saving_api.py in load_model(filepath, custom_objects, compile, safe_mode)
#     204         )
#     205     else:
# --> 206         raise ValueError(
#     207             f"File format not supported: filepath={filepath}. "
#     208             "Keras 3 only supports V3 `.keras` files and "
#
# ...

# %%
from tensorflow.keras.models import load_model

model = load_model('Untitled2.ipynb.h5')  # Replace with actual name
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-805140413.py in <cell line: 0>()
#       1 from tensorflow.keras.models import load_model
#       2
# ----> 3 model = load_model('Untitled2.ipynb.h5')  # Replace with actual name
#
# /usr/local/lib/python3.11/dist-packages/keras/src/saving/saving_api.py in load_model(filepath, custom_objects, compile, safe_mode)
#     194         )
#     195     if str(filepath).endswith((".h5", ".hdf5")):
# --> 196         return legacy_h5_format.load_model_from_hdf5(
#     197             filepath, custom_objects=custom_objects, compile=compile
#     198         )
#
# /usr/local/lib/python3.11/dist-packages/keras/src/legacy/saving/legacy_h5_format.py in load_model_from_hdf5(filepath, custom_objects, compile)
#     114     opened_new_file = not isinstance(filepath, h5py.File)
#     115     if opened_new_file:
# ...

# %%
os.listdir()
# Out:
# ['.config',
#  'archive (8) (1).zip',
#  'dataset',
#  'archive (7).zip',
#  'archive (7) (1).zip',
#  'archive (8).zip',
#  'sample_data']

# %%
# 1. Install Gradio
# !pip install gradio

# 2. Import libraries
import gradio as gr
import numpy as np
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image
import tensorflow as tf

# 3. Load the model (make sure you upload this .h5 file or mount Google Drive)
model = load_model('model.h5')  # Replace with your model name

# 4. Define prediction function
def predict_image(img):
    img = img.resize((224, 224))  # Adjust to your model input size
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0) / 255.0
    prediction = model.predict(img_array)

    # Handle binary/multiclass as needed:
    if prediction.shape[1] == 1:
        return "Tumor Detected" if prediction[0][0] > 0.5 else "No Tumor"
    else:
        class_idx = np.argmax(prediction[0])
        return f"Class {class_idx} (Confidence: {prediction[0][class_idx]:.2f})"

# 5. Create Gradio interface
interface = gr.Interface(
    fn=predict_image,
    inputs=gr.Image(type="pil"),
    outputs="text",
    title="Brain Tumor Detection",
    description="Upload an MRI image to predict tumor presence."
)

# 6. Launch UI
interface.launch()
# Out:
# ...
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-1554727321.py in <cell line: 0>()
#      10
#      11 # 3. Load the model (make sure you upload this .h5 file or mount Google Drive)
# ---> 12 model = load_model('model.h5')  # Replace with your model name
#      13
#      14 # 4. Define prediction function
#
# /usr/local/lib/python3.11/dist-packages/keras/src/saving/saving_api.py in load_model(filepath, custom_objects, compile, safe_mode)
#     194         )
#     195     if str(filepath).endswith((".h5", ".hdf5")):
# --> 196         return legacy_h5_format.load_model_from_hdf5(
#     197             filepath, custom_objects=custom_objects, compile=compile
#     198         )
#
# /usr/local/lib/python3.11/dist-packages/keras/src/legacy/saving/legacy_h5_format.py in load_model_from_hdf5(filepath, custom_objects, compile)
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-68559f37-7387-4a19-8511-a096fe2528c9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-68559f37-7387-4a19-8511-a096fe2528c9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import gradio as gr
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Flatten, Dropout, Dense
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.preprocessing import image

# %%
IMAGE_SIZE = 128  # or 224, depending on training
unique_labels = ['No Tumor', 'Tumor']  # change to your actual class names

base_model = MobileNetV2(weights=None, include_top=False, input_shape=(IMAGE_SIZE, IMAGE_SIZE, 3), pooling='avg')

model = Sequential([
    Input(shape=(IMAGE_SIZE, IMAGE_SIZE, 3)),
    base_model,
    Flatten(),
    Dropout(0.3),
    Dense(128, activation='relu'),
    Dropout(0.2),
    Dense(len(unique_labels), activation='softmax')
])

# Optional: Load weights if saved separately
# model.load_weights('your_weights.h5')

# %%
def predict_image(img):
    img = img.resize((IMAGE_SIZE, IMAGE_SIZE))
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0) / 255.0
    prediction = model.predict(img_array)[0]
    label_idx = np.argmax(prediction)
    confidence = prediction[label_idx]
    return f"Prediction: {unique_labels[label_idx]} (Confidence: {confidence:.2f})"

# %%
interface = gr.Interface(
    fn=predict_image,
    inputs=gr.Image(type="pil"),
    outputs="text",
    title="Brain Tumor Classifier",
    description="Upload an MRI scan to detect tumor presence."
)

interface.launch()
# Out:
# It looks like you are running Gradio on a hosted Jupyter notebook, which requires `share=True`. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://0b7c124f91f38d579a.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://0b7c124f91f38d579a.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
